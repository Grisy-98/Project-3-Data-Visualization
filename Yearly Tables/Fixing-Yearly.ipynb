# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json

# %%
df_2018 = pd.read_csv("/Users/michaelsanchez/Documents/Data Analytics Courses/Week 12 Mongo/Project-3-Data-Visualization/Yearly Tables/2018_table.csv")
df_2019 = pd.read_csv("/Users/michaelsanchez/Documents/Data Analytics Courses/Week 12 Mongo/Project-3-Data-Visualization/Yearly Tables/2019_table.csv", index_col=0)
df_2020 = pd.read_csv("/Users/michaelsanchez/Documents/Data Analytics Courses/Week 12 Mongo/Project-3-Data-Visualization/Yearly Tables/2020_table.csv", index_col=0)
df_2021 = pd.read_csv("/Users/michaelsanchez/Documents/Data Analytics Courses/Week 12 Mongo/Project-3-Data-Visualization/Yearly Tables/2021_table.csv", index_col=0)
df_2022 = pd.read_csv("/Users/michaelsanchez/Documents/Data Analytics Courses/Week 12 Mongo/Project-3-Data-Visualization/Yearly Tables/2022_table.csv", index_col=0)
df_2018.dtypes
# Out:
# Unnamed: 0                              int64
# Zip Code                                int64
# 2018 Median Contract Rent               int64
# Median Monthly Cost                     int64
# Total Median Monthly Cost               int64
# Median Monthly Cost With Mortgage       int64
# Median Monthly Cost Without Mortgage    int64
# Total Housing Units                     int64
# Housing Units Owned                     int64
# Housing Units Rented                    int64
# dtype: object

# %%
df_2018 = df_2018.drop(df_2018[df_2018["2018 Median Contract Rent"]== -666666666].index) 
df_2018 = df_2018.drop(df_2018[df_2018["Median Monthly Cost"]== -666666666].index) 
df_2018 = df_2018.drop(df_2018[df_2018["Total Median Monthly Cost"]== -666666666].index) 
df_2018 = df_2018.drop(df_2018[df_2018["Median Monthly Cost With Mortgage"]== -666666666].index) 
df_2018 = df_2018.drop(df_2018[df_2018["Median Monthly Cost Without Mortgage"]== -666666666].index) 




df_2018
# Out:
#      Unnamed: 0  Zip Code  2018 Median Contract Rent  Median Monthly Cost  \
# 0             0     76501                        523               117400
# 1             1     76502                        930               159300
# 2             2     76504                        680                93100
# 3             3     76511                        393                93100
# 4             4     76513                        668               167400
# ..          ...       ...                        ...                  ...
# 143         143     78759                       1119               414600
# 144         144     78942                        653               115400
# 145         145     78946                        743               166100
# 146         146     78947                        531               166400
# 147         147     78953                       1118               151900
#
#      Total Median Monthly Cost  Median Monthly Cost With Mortgage  \
# ...

# %%
df_2018 = df_2018.drop(columns=["Unnamed: 0"])
df_2018
# Out:
#      Zip Code  2018 Median Contract Rent  Median Monthly Cost  \
# 0       76501                        523               117400
# 1       76502                        930               159300
# 2       76504                        680                93100
# 3       76511                        393                93100
# 4       76513                        668               167400
# ..        ...                        ...                  ...
# 143     78759                       1119               414600
# 144     78942                        653               115400
# 145     78946                        743               166100
# 146     78947                        531               166400
# 147     78953                       1118               151900
#
#      Total Median Monthly Cost  Median Monthly Cost With Mortgage  \
# 0                          754                               1093
# 1                         1122                               1404
# ...

# %%
df_2018 = df_2018.reset_index()
df_2018 = df_2018.drop(['index'], axis =1)
df_2018
# Out:
#      Zip Code  2018 Median Contract Rent  Median Monthly Cost  \
# 0       76501                        523               117400
# 1       76502                        930               159300
# 2       76504                        680                93100
# 3       76511                        393                93100
# 4       76513                        668               167400
# ..        ...                        ...                  ...
# 142     78759                       1119               414600
# 143     78942                        653               115400
# 144     78946                        743               166100
# 145     78947                        531               166400
# 146     78953                       1118               151900
#
#      Total Median Monthly Cost  Median Monthly Cost With Mortgage  \
# 0                          754                               1093
# 1                         1122                               1404
# ...

# %%
df_2018.to_csv("2018_table.csv", index = False)

# %%
df_2019 = df_2019.drop(df_2019[df_2019["2019 Median Contract Rent"]== -666666666].index) 
df_2019 = df_2019.drop(df_2019[df_2019["Median Monthly Cost"]== -666666666].index) 
df_2019 = df_2019.drop(df_2019[df_2019["Total Median Monthly Cost"]== -666666666].index) 
df_2019 = df_2019.drop(df_2019[df_2019["Median Monthly Cost With Mortgage"]== -666666666].index) 
df_2019 = df_2019.drop(df_2019[df_2019["Median Monthly Cost Without Mortgage"]== -666666666].index) 

df_2019
# Out:
#      Zip Code  2019 Median Contract Rent  Median Monthly Cost  \
# 0       76501                        534               121000
# 1       76502                        972               163600
# 2       76504                        707                96100
# 3       76511                        505                91500
# 4       76513                        744               173000
# ..        ...                        ...                  ...
# 159     78759                       1154               444100
# 160     78942                        661               125300
# 161     78946                        763               117600
# 162     78947                        616               192300
# 164     78953                       1315               161800
#
#      Total Median Monthly Cost  Median Monthly Cost With Mortgage  \
# 0                          783                               1134
# 1                         1143                               1430
# ...

# %%
df_2019.to_csv("2019_table.csv", index = False)

# %%
df_2020 = df_2020.drop(df_2020[df_2020["2020 Median Contract Rent"]== -666666666].index) 
df_2020 = df_2020.drop(df_2020[df_2020["Median Monthly Cost"]== -666666666].index) 
df_2020 = df_2020.drop(df_2020[df_2020["Total Median Monthly Cost"]== -666666666].index) 
df_2020 = df_2020.drop(df_2020[df_2020["Median Monthly Cost With Mortgage"]== -666666666].index) 
df_2020 = df_2020.drop(df_2020[df_2020["Median Monthly Cost Without Mortgage"]== -666666666].index) 

df_2020
# Out:
#      Zip Code  2020 Median Contract Rent  Median Monthly Cost  \
# 0       76501                        550               120600
# 1       76502                        931               166500
# 2       76504                        729                98500
# 3       76511                        359               101700
# 4       76513                        777               179300
# ..        ...                        ...                  ...
# 159     78759                       1175               459600
# 160     78942                        668               150400
# 161     78946                        769               123000
# 162     78947                        719               210100
# 164     78953                        996               161000
#
#      Total Median Monthly Cost  Median Monthly Cost With Mortgage  \
# 0                          777                               1138
# 1                         1145                               1442
# ...

# %%
df_2020.to_csv("2020_table.csv", index = False)

# %%
df_2021 = df_2021.drop(df_2021[df_2021["2021 Median Contract Rent"]== -666666666].index) 
df_2021 = df_2021.drop(df_2021[df_2021["Median Monthly Cost"]== -666666666].index) 
df_2021 = df_2021.drop(df_2021[df_2021["Total Median Monthly Cost"]== -666666666].index) 
df_2021 = df_2021.drop(df_2021[df_2021["Median Monthly Cost With Mortgage"]== -666666666].index) 
df_2021 = df_2021.drop(df_2021[df_2021["Median Monthly Cost Without Mortgage"]== -666666666].index) 

df_2021
# Out:
#      Zip Code  2021 Median Contract Rent  Median Monthly Cost  \
# 0       76501                        597               120400
# 1       76502                        969               183700
# 2       76504                        759               114400
# 3       76511                        364               120600
# 4       76513                        838               189700
# ..        ...                        ...                  ...
# 158     78758                       1197               295700
# 159     78759                       1270               485800
# 160     78942                        718               168700
# 161     78946                        838               176100
# 162     78947                        714               224700
#
#      Total Median Monthly Cost  Median Monthly Cost With Mortgage  \
# 0                          848                               1157
# 1                         1209                               1517
# ...

# %%
df_2021.to_csv('2021_table.csv', index = False)

# %%
df_2022 = df_2022.drop(df_2022[df_2022["2022 Median Contract Rent"]== -666666666].index) 
df_2022 = df_2022.drop(df_2022[df_2022["Median Monthly Cost"]== -666666666].index) 
df_2022 = df_2022.drop(df_2022[df_2022["Total Median Monthly Cost"]== -666666666].index) 
df_2022 = df_2022.drop(df_2022[df_2022["Median Monthly Cost With Mortgage"]== -666666666].index) 
df_2022 = df_2022.drop(df_2022[df_2022["Median Monthly Cost Without Mortgage"]== -666666666].index) 

df_2022
# Out:
#      Zip Code  2022 Median Contract Rent  Median Monthly Cost  \
# 0       76501                        675               147700
# 1       76502                       1091               222600
# 2       76504                        836               142600
# 3       76511                        375               150200
# 4       76513                        961               235500
# ..        ...                        ...                  ...
# 160     78942                        794               180500
# 161     78946                        846               164200
# 162     78947                        694               235300
# 163     78948                        529               238600
# 164     78953                       1341               264100
#
#      Total Median Monthly Cost  Median Monthly Cost With Mortgage  \
# 0                          882                               1320
# 1                         1315                               1646
# ...

# %%
df_2022.to_csv('2022_table.csv', index = False)
